# %%
def say_hello():
    return "Hello!"

# %%
say_hello()
# Out:
# 'Hello!'

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def say_hello():\n    return "Hello!"',
#   'say_hello()',
#   'globals()'],
#  '_oh': {2: 'Hello!'},
#  '_dh': [PosixPath('/home/firas/Downloads/pyfrad/11-functions')],
#  'In': ['',
#   'def say_hello():\n    return "Hello!"',
#   'say_hello()',
#   'globals()'],
#  'Out': {2: 'Hello!'},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7c2a904ca660>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7c2a90365d30>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7c2a90365d30>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
# ...

# %%
a = 100

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def say_hello():\n    return "Hello!"',
#   'say_hello()',
#   'globals()',
#   'a = 100',
#   'globals()'],
#  '_oh': {2: 'Hello!', 3: {...}},
#  '_dh': [PosixPath('/home/firas/Downloads/pyfrad/11-functions')],
#  'In': ['',
#   'def say_hello():\n    return "Hello!"',
#   'say_hello()',
#   'globals()',
#   'a = 100',
#   'globals()'],
#  'Out': {2: 'Hello!', 3: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7c2a904ca660>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7c2a90365d30>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7c2a90365d30>,
# ...

# %%
a
# Out:
# 100

# %%
type(say_hello)
# Out:
# function

# %%
result = say_hello()

# %%
result
# Out:
# 'Hello!'

# %%
f = say_hello()

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def say_hello():\n    return "Hello!"',
#   'say_hello()',
#   'globals()',
#   'a = 100',
#   'globals()',
#   'a',
#   'type(say_hello)',
#   'result = say_hello()',
#   'result',
#   'f = say_hello()',
#   'globals()'],
#  '_oh': {2: 'Hello!', 3: {...}, 5: {...}, 6: 100, 7: function, 9: 'Hello!'},
#  '_dh': [PosixPath('/home/firas/Downloads/pyfrad/11-functions')],
#  'In': ['',
#   'def say_hello():\n    return "Hello!"',
#   'say_hello()',
#   'globals()',
#   'a = 100',
#   'globals()',
#   'a',
#   'type(say_hello)',
#   'result = say_hello()',
#   'result',
#   'f = say_hello()',
#   'globals()'],
#  'Out': {2: 'Hello!', 3: {...}, 5: {...}, 6: 100, 7: function, 9: 'Hello!'},
# ...

# %%
l1 = [1,2,3]

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def say_hello():\n    return "Hello!"',
#   'say_hello()',
#   'globals()',
#   'a = 100',
#   'globals()',
#   'a',
#   'type(say_hello)',
#   'result = say_hello()',
#   'result',
#   'f = say_hello()',
#   'globals()',
#   'l1 = [1,2,3]',
#   'globals()'],
#  '_oh': {2: 'Hello!',
#   3: {...},
#   5: {...},
#   6: 100,
#   7: function,
#   9: 'Hello!',
#   11: {...}},
#  '_dh': [PosixPath('/home/firas/Downloads/pyfrad/11-functions')],
#  'In': ['',
#   'def say_hello():\n    return "Hello!"',
#   'say_hello()',
#   'globals()',
#   'a = 100',
#   'globals()',
#   'a',
#   'type(say_hello)',
#   'result = say_hello()',
#   'result',
#   'f = say_hello()',
#   'globals()',
# ...

# %%
l2 = l1

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def say_hello():\n    return "Hello!"',
#   'say_hello()',
#   'globals()',
#   'a = 100',
#   'globals()',
#   'a',
#   'type(say_hello)',
#   'result = say_hello()',
#   'result',
#   'f = say_hello()',
#   'globals()',
#   'l1 = [1,2,3]',
#   'globals()',
#   'l2 = l1',
#   'globals()'],
#  '_oh': {2: 'Hello!',
#   3: {...},
#   5: {...},
#   6: 100,
#   7: function,
#   9: 'Hello!',
#   11: {...},
#   13: {...}},
#  '_dh': [PosixPath('/home/firas/Downloads/pyfrad/11-functions')],
#  'In': ['',
#   'def say_hello():\n    return "Hello!"',
#   'say_hello()',
#   'globals()',
#   'a = 100',
#   'globals()',
#   'a',
#   'type(say_hello)',
#   'result = say_hello()',
#   'result',
# ...

# %%
    l2 is l1
# Out:
# True

# %%
say_hello()
# Out:
# 'Hello!'

# %%
f()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 f()
#
# TypeError: 'str' object is not callable

# %%
f
# Out:
# 'Hello!'

# %%
type(f)
# Out:
# str

# %%
say_hello.__name__
# Out:
# 'say_hello'

# %%
f.__name__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 f.__name__
#
# AttributeError: 'str' object has no attribute '__name__'

# %%
f = say_hello()

# %%
f()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 f()
#
# TypeError: 'str' object is not callable

# %%
def add(a,b,c):
    print(f'a={a}')
    print(f'b={b}')
    print(f'c={c}')
    return a+b+c

# %%
result = add(1,2,3)
# Out:
# a=1
# b=2
# c=3

# %%
result
# Out:
# 6

# %%
def add(a,b,c):
    print('initial namespace:',locals())
    sum_ = a+b+c
    print('initial namespace:',locals())

    return a+b+c

# %%
add(1,2,3)
# Out:
# initial namespace: {'a': 1, 'b': 2, 'c': 3}
# initial namespace: {'a': 1, 'b': 2, 'c': 3, 'sum_': 6}
# 6

# %%
7:25
