# %%
round(0.325)
# Out:
# 0

# %%
round(0.875)
# Out:
# 1

# %%
round(13.5)
# Out:
# 14

# %%
round(12.5)
# Out:
# 12

# %%
round(0.125,1)
# Out:
# 0.1

# %%
round(0.125,2)
# Out:
# 0.12

# %%
round(123456,-1)
# Out:
# 123460

# %%
round(123456,-2)
# Out:
# 123500

# %%
round(123456,-3)
# Out:
# 123000

# %%
round(1235,-1)
# Out:
# 1240

# %%
round(1245,-1)
# Out:
# 1240

# %%
round(0.125,2)
# Out:
# 0.12

# %%
round(0.325,2)
# Out:
# 0.33

# %%
format(0.325,'.20f')
# Out:
# '0.32500000000000001110'
