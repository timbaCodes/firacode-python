# %%
l = [1,10,2,9,3,8]
t = (1,10,2,9,3,8)
s = {1,10,2,9,3,8}

# %%
sorted(l)
# Out:
# [1, 2, 3, 8, 9, 10]

# %%
l
# Out:
# [1, 10, 2, 9, 3, 8]

# %%
sorted(t)
# Out:
# [1, 2, 3, 8, 9, 10]

# %%
t
# Out:
# (1, 10, 2, 9, 3, 8)

# %%
sorted(s)
# Out:
# [1, 2, 3, 8, 9, 10]

# %%
sorted(l,reverse=True)
# Out:
# [10, 9, 8, 3, 2, 1]

# %%
# ?sorted

# %%
sorted(iterable=l,reverse=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sorted(iterable=l,reverse=True)
#
# TypeError: sorted expected 1 argument, got 0

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65

# %%
'A' < 'a'
# Out:
# True

# %%
sorted(('a','b','c'))
# Out:
# ['a', 'b', 'c']

# %%
sorted('azbycz')
# Out:
# ['a', 'b', 'c', 'y', 'z', 'z']

# %%
sorted('aAbBxX')
# Out:
# ['A', 'B', 'X', 'a', 'b', 'x']

# %%
ord('X')
# Out:
# 88

# %%
sorted(['Zebra','apple'])
# Out:
# ['Zebra', 'apple']

# %%
sorted(['Zebra','apple','atom'])
# Out:
# ['Zebra', 'apple', 'atom']

# %%
l = [1,10,2,9,3,8]

# %%
sorted_ascending = sorted(l)

# %%
sorted_ascending
# Out:
# [1, 2, 3, 8, 9, 10]

# %%
min(l)
# Out:
# 1

# %%
max(l)
# Out:
# 10

# %%
sorted([])
# Out:
# []

# %%
min([])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 min([])
#
# ValueError: min() iterable argument is empty

# %%
min([],default=0)
# Out:
# 0
