# %%
data = ['a','ab','abc','abcd']

# %%
lengths = [len(element) for element in data]

# %%
lengths
# Out:
# [1, 2, 3, 4]

# %%
lengths = (len(element) for element in data)

# %%
lengths
# Out:
# <generator object <genexpr> at 0x7b98907b8930>

# %%
3 in lengths
# Out:
# True

# %%
def my_len(x):
    return len(x)

# %%
lengths = (my_len(element) for element in data)

# %%
list(lengths)
# Out:
# [1, 2, 3, 4]

# %%
lengths = map(len,data)

# %%
list(lengths)
# Out:
# [1, 2, 3, 4]

# %%
lengths

# %%
list(lengths)
# Out:
# []
