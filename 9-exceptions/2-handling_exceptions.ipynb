# %%
try:
    1 /0
except ZeroDivisionError as ex:
    print(f'Exception occured: {type(ex)}, {ex}')
print('code continues running here')
# Out:
# Exception occured: <class 'ZeroDivisionError'>, division by zero
# code continues running here

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero

# %%
l = [1,2,3,4,5]

while len(l) > 0:
    print(l.pop())

print('all done')
# Out:
# 5
# 4
# 3
# 2
# 1
# all done

# %%
l = [1,2,3,4,5]
while True:
    print(l.pop())
print('all done')
# Out:
# 5
# 4
# 3
# 2
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 l = [1,2,3,4,5]
#       2 while True:
# ----> 3     print(l.pop())
#       4 print('all done')
#
# IndexError: pop from empty list

# %%
l = [1,2,3,4,5]
try:
    while True:
        print(l.pop())
except IndexError:
    # index error means list is now empty - expected behavior
    print('all done - all elements have been popped')
print('code resumes here ...')
# Out:
# 5
# 4
# 3
# 2
# 1
# all done - all elements have been popped
# code resumes here ...

# %%
l = [1,2,3,4,5]
try:
    while True:
        print(l.pop())
except Exception:
    # index error means list is now empty - expected behavior
    print('something unexcpected happen')
print('code resumes here ...')
# Out:
# 5
# 4
# 3
# 2
# 1
# something unexcpected happen
# code resumes here ...

# %%
l
# Out:
# []

# %%
l = (1,2,3,4,5)
try:
    while True:
        print(l.pop())
except Exception:
    # index error means list is now empty - expected behavior
    print('something unexcpected happen')
print('code resumes here ...')
# Out:
# something unexcpected happen
# code resumes here ...

# %%
l
# Out:
# (1, 2, 3, 4, 5)

# %%
l = (1,2,3,4,5)
try:
    while True:
        print(l.pop())
except IndexError:
    # index error means list is now empty - expected behavior
    print('something unexcpected happen')
print('code resumes here ...')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 4
#       2 try:
#       3     while True:
# ----> 4         print(l.pop())
#       5 except IndexError:
#       6     # index error means list is now empty - expected behavior
#       7     print('something unexcpected happen')
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
10 + 'abc'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 10 + 'abc'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
10 + None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 10 + None
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
data = [10,20,10,10,5,10]

sum_data= 0
count_data = 0

for element in data:
    sum_data +=element
    count_data+=1
average = sum_data/count_data
print(f'average: = {average}')
# Out:
# average: = 10.833333333333334

# %%
data = []

sum_data= 0
count_data = 0

for element in data:
    sum_data +=element
    count_data+=1
average = sum_data/count_data
print(f'average: = {average}')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 9
#       7     sum_data +=element
#       8     count_data+=1
# ----> 9 average = sum_data/count_data
#      10 print(f'average: = {average}')
#
# ZeroDivisionError: division by zero

# %%
data = []

if len(data) ==0:
    average = 0
else:
    sum_data= 0
    count_data = 0

    for element in data:
        sum_data +=element
        count_data+=1
    average = sum_data/count_data
print(f'average: = {average}')
# Out:
# average: = 0

# %%
data = [10,20,'abc']

sum_data= 0
count_data = 0
try:
    for element in data:
        sum_data +=element
        count_data+=1
    average = sum_data/count_data
except ZeroDivisionError:
    average = 0
except TypeError:
    average = 0
print(f'average: = {average}')
# Out:
# average: = 0

# %%
data = [10,20,'abc']

sum_data= 0
count_data = 0
try:
    for element in data:
        try:
            sum_data +=element
            count_data+=1
        except TypeError:
            pass

    average = sum_data/count_data
except ZeroDivisionError:
    average = 0

print(f'average: = {average}')
# Out:
# average: = 15.0

# %%
data = []

sum_data= 0
count_data = 0
try:
    for element in data:
        try:
            sum_data +=element
            count_data+=1
        except TypeError:
            pass

    average = sum_data/count_data
except ZeroDivisionError:
    average = 0

print(f'average: = {average}')
# Out:
# average: = 0

# %%
data = [10,20,30]

sum_data= 0
count_data = 0
try:
    for element in data:
        try:
            sum_data +=element
            count_data+=1
        except TypeError:
            pass

    average = sum_data/count_data
except ZeroDivisionError:
    average = 0

print(f'average: = {average}')
# Out:
# average: = 20.0

# %%
try:
    1/0
except Exception as ex:
    print(f'logging error: {ex}')
print('programm stil running ...')
# Out:
# logging error: division by zero
# programm stil running ...

# %%
try:
    1/0
except Exception as ex:
    print(f'logging error: {ex}')
    raise
print('programm stil running ...')
# Out:
# logging error: division by zero
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[30], line 2
#       1 try:
# ----> 2     1/0
#       3 except Exception as ex:
#       4     print(f'logging error: {ex}')
#
# ZeroDivisionError: division by zero

# %%
try:
    raise ValueError('custom message')
except ValueError as ex:
    print(f'handle a value error: {ex}')
finally:
    print('this is always excuted')
print('all done')
# Out:
# handle a value error: custom message
# this is always excuted
# all done

# %%
try:
    raise TypeError('custom message')
except ValueError as ex:
    print(f'handle a value error: {ex}')
finally:
    print('this is always excuted')
print('all done')
# Out:
# this is always excuted
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 try:
# ----> 2     raise TypeError('custom message')
#       3 except ValueError as ex:
#       4     print(f'handle a value error: {ex}')
#
# TypeError: custom message

# %%
try:
    raise ValueError('custom message')
except ValueError as ex:
    print(f'handle a value error: {ex}')
    raise TypeError('changing to a type error')
finally:
    print('this is always excuted')
print('all done')
# Out:
# handle a value error: custom message
# this is always excuted
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 try:
# ----> 2     raise ValueError('custom message')
#       3 except ValueError as ex:
#
# ValueError: custom message
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 5
#       3 except ValueError as ex:
#       4     print(f'handle a value error: {ex}')
# ----> 5     raise TypeError('changing to a type error')
#       6 finally:
#       7     print('this is always excuted')
#
# TypeError: changing to a type error

# %%
try:
    print('nothing to see here...')
except ValueError as ex:
    print('hendled a valueerror')
finally:
    print('this always excutes')
# Out:
# nothing to see here...
# this always excutes

# %%
try:
    print('nothing to see here...')
    1/0
finally:
    print('this always excutes')
# Out:
# nothing to see here...
# this always excutes
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[36], line 3
#       1 try:
#       2     print('nothing to see here...')
# ----> 3     1/0
#       4 finally:
#       5     print('this always excutes')
#
# ZeroDivisionError: division by zero
