# %% [markdown]
# Generators

# %%
squares = [i ** 2 for i in range(5)]

# %%
squares
# Out:
# [0, 1, 4, 9, 16]

# %%
squares = (i ** 2 for i in range(5))

# %%
squares
# Out:
# <generator object <genexpr> at 0x73b7302e8110>

# %%
type(squares)
# Out:
# generator

# %%
for i in squares:
    print(i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
for i in squares:
    print(i)

# %%
squares = (i ** 2 for i in range(5))

# %%
for i in squares:
    print(i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
squares = (i ** 2 for i in range(5))

# %%
iter(squares) is squares
# Out:
# True

# %%
next(squares)
# Out:
# 0

# %%
next(squares)
# Out:
# 1

# %%
next(squares)
# Out:
# 4

# %%
next(squares)
# Out:
# 9

# %%
next(squares)
# Out:
# 16

# %%
next(squares)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 next(squares)
#
# StopIteration:

# %%
squares = (i ** 2 for i in range(5))

# %%
3 in squares
# Out:
# False

# %%
list(squares)
# Out:
# []

# %%
squares = (i ** 2 for i in range(5))

# %%
4 in squares
# Out:
# True

# %%
list(squares)
# Out:
# [9, 16]

# %%
from timeit import timeit

# %%
timeit('[i ** 2 for i in range(25_000_000)]',number=1)
# Out:
# 1.647807389999798

# %%
timeit('(i ** 2 for i in range(25_000_000))',number=1)
# Out:
# 3.864999598590657e-06
