# %%
import math

# %%
import random as rnd

# %%
math
# Out:
# <module 'math' (built-in)>

# %%
rnd
# Out:
# <module 'random' from '/home/firas/.local/share/mise/installs/python/3.13.4/lib/python3.13/random.py'>

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
from math import sqrt

# %%
sqrt
# Out:
# <function math.sqrt(x, /)>

# %%
math
# Out:
# <module 'math' (built-in)>

# %%
sqrt(4)
# Out:
# 2.0

# %%
import math

sqrt = math.sqrt

# %%
sqrt
# Out:
# <function math.sqrt(x, /)>

# %%
from fractions import Fraction

# %%
Fraction
# Out:
# fractions.Fraction

# %%
fractions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 fractions
#
# NameError: name 'fractions' is not defined

# %%
import math
from math import pi,sqrt,sin

# %%
math.gcd(3,7)
# Out:
# 1

# %%
sqrt(4)
# Out:
# 2.0
