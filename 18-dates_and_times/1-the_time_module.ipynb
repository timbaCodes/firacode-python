# %% [markdown]
# The time Module

# %%
from time import perf_counter, sleep

# %%
start = perf_counter()

# %%
start
# Out:
# 635.372766725

# %%
end = perf_counter()

# %%
end
# Out:
# 645.484459425

# %%
start - end
# Out:
# -10.111692699999935

# %%
start = perf_counter()
sleep(3)
end = perf_counter()
elapsed = end - start
print(elapsed)
# Out:
# 3.0003246899999567

# %%
from time import gmtime

# %%
gmtime(1_000_000_000)
# Out:
# time.struct_time(tm_year=2001, tm_mon=9, tm_mday=9, tm_hour=1, tm_min=46, tm_sec=40, tm_wday=6, tm_yday=252, tm_isdst=0)

# %%
gmtime(0)
# Out:
# time.struct_time(tm_year=1970, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=1, tm_isdst=0)

# %%
gmtime(-1_000_000_000)
# Out:
# time.struct_time(tm_year=1938, tm_mon=4, tm_mday=24, tm_hour=22, tm_min=13, tm_sec=20, tm_wday=6, tm_yday=114, tm_isdst=0)

# %%
import time

# %%
time.time()
# Out:
# 1755773405.231452

# %%
from time import time

# %%
time()
# Out:
# 1755773429.0562303

# %%
gmtime(time())
# Out:
# time.struct_time(tm_year=2025, tm_mon=8, tm_mday=21, tm_hour=10, tm_min=50, tm_sec=39, tm_wday=3, tm_yday=233, tm_isdst=0)

# %%
current = gmtime(time())

# %%
current[0]
# Out:
# 2025

# %%
current.tm_year
# Out:
# 2025

# %%
now = time()

# %%
tomorrow = now + (24 * 60 * 60)

# %%
gmtime(now),gmtime(tomorrow)
# Out:
# (time.struct_time(tm_year=2025, tm_mon=8, tm_mday=21, tm_hour=10, tm_min=52, tm_sec=35, tm_wday=3, tm_yday=233, tm_isdst=0),
#  time.struct_time(tm_year=2025, tm_mon=8, tm_mday=22, tm_hour=10, tm_min=52, tm_sec=35, tm_wday=4, tm_yday=234, tm_isdst=0))

# %%
tomorrow - now
# Out:
# 86400.0

# %%
from calendar import timegm

# %%
now_epoch = time()

# %%
now_epoch
# Out:
# 1755773651.112872

# %%
now_struc = gmtime(now_epoch)

# %%
now_struc
# Out:
# time.struct_time(tm_year=2025, tm_mon=8, tm_mday=21, tm_hour=10, tm_min=54, tm_sec=11, tm_wday=3, tm_yday=233, tm_isdst=0)

# %%
timegm(now_struc)
# Out:
# 1755773651

# %%
now = gmtime(time())

# %%
now
# Out:
# time.struct_time(tm_year=2025, tm_mon=8, tm_mday=21, tm_hour=10, tm_min=56, tm_sec=15, tm_wday=3, tm_yday=233, tm_isdst=0)

# %%
from time import strftime

# %%
strftime('%Y/%m/%d',now)
# Out:
# '2025/08/21'

# %%
strftime('%A is the best day of the week!',now)
# Out:
# 'Thursday is the best day of the week!'

# %%
d = '12/11/10'

# %%
d = '2012-11-10'

# %%
from time import strptime

# %%
strptime(d,'%Y-%m-%d')
# Out:
# time.struct_time(tm_year=2012, tm_mon=11, tm_mday=10, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=315, tm_isdst=-1)

# %%
s= 'Monday , April 18, in the year 2020 CE'

# %%
fmt = '%A , %B %d, in the year %Y CE'

# %%
strptime(s,fmt)
# Out:
# time.struct_time(tm_year=2020, tm_mon=4, tm_mday=18, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=109, tm_isdst=-1)
